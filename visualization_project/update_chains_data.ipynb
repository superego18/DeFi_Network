# %%
import pandas as pd

# %%
df = pd.read_csv("data/chains_data_v5.csv")

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0         chain          protocol  \
# 0                0           0   (C)Ethereum              Lido
# 1                1           1   (C)Ethereum          MakerDAO
# 2                2           2   (C)Ethereum           AAVE V2
# 3                3           3   (C)Ethereum           AAVE V3
# 4                4           4   (C)Ethereum           AAVE V1
# ...            ...         ...           ...               ...
# 1431          1431        1431    (C)Echelon           ECHSWAP
# 1432          1432        1432     (C)zkSync  Phezzan Protocol
# 1433          1433        1433     (C)zkSync            ZigZag
# 1434          1434        1434       (C)Coti     COTI Treasury
# 1435          1435        1435  (C)Thorchain          THORSwap
#
#      protocol_category                                    protocol_chains  \
# 0       Liquid Staking  ['Ethereum', 'Solana', 'Moonbeam', 'Moonriver'...
# ...

# %%
df.loc[df['chain'] == '(C)Ethereum']
# Out:
#     Unnamed: 0.1  Unnamed: 0        chain                     protocol  \
# 0              0           0  (C)Ethereum                         Lido
# 1              1           1  (C)Ethereum                     MakerDAO
# 2              2           2  (C)Ethereum                      AAVE V2
# 3              3           3  (C)Ethereum                      AAVE V3
# 4              4           4  (C)Ethereum                      AAVE V1
# 5              5           5  (C)Ethereum                     Aave Arc
# 6              6           6  (C)Ethereum                        Curve
# 7              7           7  (C)Ethereum               Convex Finance
# 8              8           8  (C)Ethereum                   Uniswap V3
# 9              9           9  (C)Ethereum                   Uniswap V2
# 10            10          10  (C)Ethereum                   Uniswap V1
# 11            11          11  (C)Ethereum                    Instadapp
# ...

# %%
df['protocol_category'].unique()
# Out:
# array(['Liquid Staking', 'CDP', 'Lending', 'Dexes', 'Yield', 'Services',
#        'Algo-Stables', 'Payments', 'Yield Aggregator', 'Derivatives',
#        'Synthetics', 'Insurance', 'Reserve Currency', 'Privacy',
#        'NFT Lending', 'Staking', 'NFT Marketplace', 'Launchpad', 'Farm',
#        'Leveraged Farming', 'Cross Chain', 'Options', 'Options Vault',
#        'RWA', 'Prediction Market', 'Indexes', 'Exotic Options', 'Gaming',
#        'Oracle'], dtype=object)

# %%
df.loc[df['protocol'] == 'Lido']['protocol_mcap'].unique()
# Out:
# array([2.06856305e+09])

# %%
df.groupby('chain').agg({'':})
